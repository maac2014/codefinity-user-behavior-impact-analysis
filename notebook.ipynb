# %%
import pandas as pd

data = pd.re0ad_csv('data.csv')

display(data)

# %%
import pandas as pd

datab = data[data['Group'] == 'B']

display(datab)

# %%
import pandas as pd

datab = data[data['Group'] == 'B']

display(datab.describe())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate exponential data
data = np.random.exponential(scale=1.0, size=1000)

# Create a DataFrame
df = pd.DataFrame(data, columns=['ExponentialData'])

# Plot the exponential distribution
plt.hist(df['ExponentialData'], bins=30, density=True, alpha=0.6, color='g')
plt.title('Exponential Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
